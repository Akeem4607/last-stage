# %%
from google.colab import drive
drive.mount('/content/gdrive')
# Out:
# Mounted at /content/gdrive

# %%
df=pd.read_csv('/content/gdrive/MyDrive/Colab Notebooks/household_power_consumption.txt',sep=';')
dt=df.copy()
df.head()
# Out:
# <ipython-input-133-28dd98cd8133>:1: DtypeWarning: Columns (2,3,4,5,6,7) have mixed types. Specify dtype option on import or set low_memory=False.
#   df=pd.read_csv('/content/gdrive/MyDrive/Colab Notebooks/household_power_consumption.txt',sep=';')
#          Date      Time Global_active_power Global_reactive_power  Voltage  \
# 0  16/12/2006  17:24:00               4.216                 0.418  234.840
# 1  16/12/2006  17:25:00               5.360                 0.436  233.630
# 2  16/12/2006  17:26:00               5.374                 0.498  233.290
# 3  16/12/2006  17:27:00               5.388                 0.502  233.740
# 4  16/12/2006  17:28:00               3.666                 0.528  235.680
#
#   Global_intensity Sub_metering_1 Sub_metering_2  Sub_metering_3
# 0           18.400          0.000          1.000            17.0
# 1           23.000          0.000          1.000            16.0
# 2           23.000          0.000          2.000            17.0
# ...

# %%
df=dt.copy()
#df['Time']= pd.to_datetime(df['Time'])

df = df.rename(columns={"Time": "ds", "Global_active_power": "y"})
df.head()
# Out:
#          Date        ds      y Global_reactive_power  Voltage  \
# 0  16/12/2006  17:24:00  4.216                 0.418  234.840
# 1  16/12/2006  17:25:00  5.360                 0.436  233.630
# 2  16/12/2006  17:26:00  5.374                 0.498  233.290
# 3  16/12/2006  17:27:00  5.388                 0.502  233.740
# 4  16/12/2006  17:28:00  3.666                 0.528  235.680
#
#   Global_intensity Sub_metering_1 Sub_metering_2  Sub_metering_3
# 0           18.400          0.000          1.000            17.0
# 1           23.000          0.000          1.000            16.0
# 2           23.000          0.000          2.000            17.0
# 3           23.000          0.000          1.000            17.0
# 4           15.800          0.000          1.000            17.0

# %%
print(df['ds'].isnull().sum())
df['y'].isnull().sum()
# Out:
# 0
# 0

# %%
df=pd.read_csv('/content/gdrive/MyDrive/Colab Notebooks/household_power_consumption.txt',sep=';')
dt=df.copy()
df['y'] = df['Global_active_power']
# Convert 'Date' and 'Time' columns to datetime format

# Select relevant columns
df.head()
# Out:
# <ipython-input-159-5389f3b02188>:1: DtypeWarning: Columns (2,3,4,5,6,7) have mixed types. Specify dtype option on import or set low_memory=False.
#   df=pd.read_csv('/content/gdrive/MyDrive/Colab Notebooks/household_power_consumption.txt',sep=';')
#          Date      Time Global_active_power Global_reactive_power  Voltage  \
# 0  16/12/2006  17:24:00               4.216                 0.418  234.840
# 1  16/12/2006  17:25:00               5.360                 0.436  233.630
# 2  16/12/2006  17:26:00               5.374                 0.498  233.290
# 3  16/12/2006  17:27:00               5.388                 0.502  233.740
# 4  16/12/2006  17:28:00               3.666                 0.528  235.680
#
#   Global_intensity Sub_metering_1 Sub_metering_2  Sub_metering_3      y
# 0           18.400          0.000          1.000            17.0  4.216
# 1           23.000          0.000          1.000            16.0  5.360
# ...

# %%
df['ds'] = pd.to_datetime(df['Date'] + ' ' + df['Time'])

# %%
df
# Out:
#                Date      Time Global_active_power Global_reactive_power  \
# 0        16/12/2006  17:24:00               4.216                 0.418
# 1        16/12/2006  17:25:00               5.360                 0.436
# 2        16/12/2006  17:26:00               5.374                 0.498
# 3        16/12/2006  17:27:00               5.388                 0.502
# 4        16/12/2006  17:28:00               3.666                 0.528
# ...             ...       ...                 ...                   ...
# 2075254  26/11/2010  20:58:00               0.946                   0.0
# 2075255  26/11/2010  20:59:00               0.944                   0.0
# 2075256  26/11/2010  21:00:00               0.938                   0.0
# 2075257  26/11/2010  21:01:00               0.934                   0.0
# 2075258  26/11/2010  21:02:00               0.932                   0.0
#
#          Voltage Global_intensity Sub_metering_1 Sub_metering_2  \
# ...

# %%
# Select relevant columns
dff = df[['ds', 'y']]

# Daily resampling and grouping
daily_data = dff.resample('D', on='ds').sum().reset_index()
# Out:
# <ipython-input-162-8add4d0f45bb>:5: FutureWarning: The default value of numeric_only in DataFrameGroupBy.sum is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   daily_data = dff.resample('D', on='ds').sum().reset_index()

# %%
# Determine the length of the dataset
x = len(daily_data)
dtt=daily_data.copy()
dtt['y']=dff['y']
# Define the training and test sets
train = dtt.iloc[:x-300]
test = dt.iloc[x-300:]

# %%
mod = Prophet()

mod.fit(train)

future = mod.make_future_dataframe(periods=300)

# predictions
forecast = mod.predict(future)
# Out:
# INFO:prophet:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.
# DEBUG:cmdstanpy:input tempfile: /tmp/tmpz8njbuiy/kto0yzk_.json
# DEBUG:cmdstanpy:input tempfile: /tmp/tmpz8njbuiy/b95b02db.json
# DEBUG:cmdstanpy:idx 0
# DEBUG:cmdstanpy:running CmdStan, num_threads: None
# DEBUG:cmdstanpy:CmdStan args: ['/usr/local/lib/python3.10/dist-packages/prophet/stan_model/prophet_model.bin', 'random', 'seed=2601', 'data', 'file=/tmp/tmpz8njbuiy/kto0yzk_.json', 'init=/tmp/tmpz8njbuiy/b95b02db.json', 'output', 'file=/tmp/tmpz8njbuiy/prophet_modelxpkherxe/prophet_model-20231205221614.csv', 'method=optimize', 'algorithm=lbfgs', 'iter=10000']
# 22:16:14 - cmdstanpy - INFO - Chain [1] start processing
# INFO:cmdstanpy:Chain [1] start processing
# 22:16:14 - cmdstanpy - INFO - Chain [1] done processing
# INFO:cmdstanpy:Chain [1] done processing

# %%
df.corrcoef()
